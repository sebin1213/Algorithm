# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
일에 순서가 있을때 사용

진입차수 : 현재 자신이 수행되기 위해 필요한 조건들 (자신을 가르키는 화살표들)

# %%
진입차수가 0인 정점을 큐에 넣음
그리고 해당 노드와 연결된 간선을 모두 제거해준다

그러면 다시 2와 5가 정점이 0이 되니 위의 과정을 반복
